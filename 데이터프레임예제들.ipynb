# %% [markdown]
# <a href="https://colab.research.google.com/github/anyoonee/ai/blob/%2Bphython/%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%84%EC%98%88%EC%A0%9C%EB%93%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# 데이터프레임 만들기
# list를 이용해 만들기
list1 = [['KFC', 1000, 4.5],
         ['McDonald',2000,3.9],
         ['SchoolFood',2500,4.2]
         ]
col_names=['food','price','rating']
df1 = pd.DataFrame(list1, col_names)
# 딕셔너리를 이용해 만들기
dic1 = {'food': {0:'KFC', 1:'McDonald', 2:'SchoolFood'},
        'price': {0:1000, 1:2000, 2:2500},
        'rating' : {0:4.5,1:3.9,2:4.2}
        }
df2 = pd.DataFrame(dic1)
df2
df2[['food','rating']]
df2['food'] # [열이름] 결과를 시리즈로 보기
df2[['food']] # [[열이름]] 결과를 데이터프레임 보기
df2.rename(columns={'food':'place'}, inplace=True)
df2
# Out:
#         place  price  rating
# 0         KFC   1000     4.5
# 1    McDonald   2000     3.9
# 2  SchoolFood   2500     4.2

# %%
# 필터링
data=[
    ["03770","3R",1510,7.36],
    ["036360","3SOFT",1790,1.65],
    ["005760","ACTS",1185,1.28]
]
columns = ["종목코드","종목명","현재가","등락률"]
df=pd.DataFrame(data=data, columns=columns)
df.set_index('종목코드',inplace=True)
df

# 1. 현재가가 1500 이상인 값
df[df['현재가']>= 1500 ]

# 2. 위 데이터프레임에서 현재가가 1,500원 이상이면서 1,700원 미만인 값만 필터링 해보세요.
cond = (df['현재가']>=1500) & (df['현재가']<1700)
df[cond]

# 3. 열을 추가하기 목표가 컬럼을 추가
df['목표가'] = df ['현재가']*0.01
df

#4. 행을 추가
df.loc['066570'] = ['LG전자',60000,3.84,60000*0.01]
# df.loc[인덱스번호] =[값들]
df

#5. 데이터 프레임 컬럼명 변경 (columns 속성) 컬럼명 변경(columns속성)
df5 = pd.DataFrame(data =[[1,2,3],[4,5,6]],columns=["A","B","C"])
df5
# 데이터 프레임 컬럼명 변경 (rename 메소드) 컬럼명 abc로 변경
df5.columns=['a','b','c']
df5
df5.rename(columns={'a':'가','b':'나','c':'다'}, inplace=True)
df5

# 7. name 속성 ndex의 name 속성을 'year'로 columns의 name 속성을 'company'로 변경하세요.
import numpy as np
data={"카카오":[np.nan,221,35],"NAVER":[52,47,3]}
index=[2019,2020,2021]
df7=pd.DataFrame(data=data, index=index)
df7
df7.index.name = "year"
df7.columns.name = "company"
print(df7.index.name)
print(df7.columns.name)

#8. 데이터프레임 reindex 컬럼의 순서를 ['NAVER', '카카오']로 재정렬해보세요.
data={"카카오":[np.nan,221,35],"NAVER":[52,47,3]}
index=[2019,2020,2021]
df8=pd.DataFrame(data=data, index=index)
df8

#9. 데이터프레임drop '카카오'와 'NAVER'컬럼을 삭제
df8.drop('카카오',axis=1)
df8.drop('NAVER',axis=1)
df8.drop(['카카오','NAVER'],axis=1)

#10. DataFrame doptna
data=[[1,2,3],[np.nan,5,6],[7,np.nan,9],[10,11,np.nan]]
df10=pd.DataFrame(data)
df10
# np.nan 값이 있는 모든 행을 제거
df10.dropna()

#11 dataframe.dropna (subset) 다음 데이터프레임에서 col2 컬럼의 값에 NaN이 포함된 행만 제거하세요.
data = [
    [1, 1, np.nan],
    [10, np.nan, 10],
    [2, 3, 4]
]
columns = ['col0', 'col1', 'col2']
df11 = pd.DataFrame(data, columns=columns)
df11
# col2컬럼값의 nan포함된 행만 제거
df11.dropna(subset='col2')

# 12.  dataframe.fillna 이전 데이터프레임의 NaN 값을 0으로 채우세요.

df11.fillna(method='ffill')
df11
#13. dataframe replace 이전 데이터프레임에서 0을 100으로 변경하세요.
df11.isna()

# 14.  DataFrame.query (14~18) 데이터프레임 query 메서드를 사용하여 종가(close)가 시가(open)보다 큰 데이터만 가져오세요.
data=[
    {"cd":"A060310", "nm":"3S", "open":2920, "close":2800},
    {"cd":"A095570", "nm":"AJ네트웍스", "open":1920, "close":1900},
    {"cd":"A006840", "nm":"AK홀딩스", "open":2020, "close":2010},
    {"cd":"A054620", "nm":"APS홀딩스", "open":3120, "close":3200}
]
df14 = pd.DataFrame(data=data)
df14 = df.set_index('cd')
df14
#종가(close)가 시가(open)보다 큰 데이터만 가져오기
df14.query('open<close')
# 15. DataFrame.query 종가(close)rk 3,000원 이상인 종목만 출력
df14.query('close>=3000')

#16. query 여러 조건 시가(open)가 2,000원 이상이고 종가(close)가 시가(open)이상인 종목을 출력하세요
df14.query('open>2000 and close>=open')

#17. query 와 str.startwith 종목명(nm)이 'A'로 시작하는 종목만 선택하세요.
df14.query("nm.str.startswith('A')")

#18. query 와 str.contains 위 데이터프레임에서 종목명에 '홀딩스'가 포함된 종목만 선택하세요.
df14.query("nm.str.contains('홀딩스)")

#19. DataFrame filter filter 메서드를 사용해서 "PER"과 "PBR" 컬럼만 선택하세요.
data = {
    "PER": [6.42, 17.63, 21.09, 13.93],
    "PBR": [1.10, 1.49, 2.06, 1.88],
    "DPS": [1416, 1716, 2994, 1755]
}
index = ["2019/12", "2020/12", "2021/12", "2022/12(E)"]
df19 = pd.DataFrame(data=data, index=index)

df19.filter(items=["PER", "PBR"])

# 20. DataFrame filter 정규식 filter 메서드의 정규식을 사용해서 'PER'과 'PBR' 컬럼을 선택하세요.
df.filter(regex="P.R", axis=1)
# 21. filter 메서드를 사용해서 예상치인 '2022/12(E)'를 제외한 나머지 로우 데이터를 선택하세요.
df19.filter(regex='12$',axis=0)

# 22.  "2022"년 데이터만 선택하세요.
df19.filter(like='2022',axis=0)
# Out:
# year
# company
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-013339e0ba07> in <cell line: 108>()
#     106 ]
#     107 df14 = pd.DataFrame(data=data)
# --> 108 df14 = df.set_index('cd')
#     109 df14
#     110 #종가(close)가 시가(open)보다 큰 데이터만 가져오기
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# ...

# %%
from datetime import datetime
import numpy as np
import pandas as pd

# %%
# 1.  데이터터프레임 위/아래 붙이기 (concat)
# df1, df2 데이터프레임을 위/아래 방향으로 연결하세요. (위에 df1이 있고 그 아래에 df2가 있어야합니다.)

columns = ['open', 'high', 'low', 'close']
index1 = [
    datetime(2022, 9, 8),
    datetime(2022, 9, 7),
    datetime(2022, 9, 6),
    datetime(2022, 9, 5),
    datetime(2022, 9, 2)
]

index2 = [
    datetime(2022, 9, 1),
    datetime(2022, 8, 31),
    datetime(2022, 8, 30),
    datetime(2022, 8, 29),
    datetime(2022, 8, 26)
]

df1 = pd.DataFrame(data=np.arange(0, 20).reshape(5,4), index=index1, columns=columns)
df2 = pd.DataFrame(data=np.arange(20,40).reshape(5,4), index=index2, columns=columns)

df1
df2

pd.concat([df1, df2], axis=0)

# 2.  데이터터프레임 위/아래 붙이기 (concat)
pd.concat([df2, df1], axis=0)

# 3. 데이터프레임 좌/우로 붙이기 (concat)
index = [
    datetime(2022, 9, 8),
    datetime(2022, 9, 7),
    datetime(2022, 9, 6),
    datetime(2022, 9, 5),
    datetime(2022, 9, 2)
]

df1 = pd.DataFrame(data=np.arange(0, 10).reshape(5,2), index=index, columns=['open', 'high'])
df2 = pd.DataFrame(data=np.arange(10,20).reshape(5,2), index=index, columns=['low', 'close'])

pd.concat([df1, df2], axis=1)

# 4. DataFrame.concat  df1, df2 데이터프레임을 위/아래로 연결하세요. concat 메서드에서 join='outer'를 사용하세요.
index1 = [
    datetime(2022, 9, 8),
    datetime(2022, 9, 7)
]

index2 = [
    datetime(2022, 9, 6),
    datetime(2022, 9, 5)
]
df1 = pd.DataFrame(np.arange(0, 6).reshape(2,3), index=index1, columns=['open', 'high', 'low'])
df2 = pd.DataFrame(np.arange(6,12).reshape(2,3), index=index2, columns=['high', 'low', 'close'])
df1
df2

pd.concat([df1, df2], axis=0, join='outer')

# 5. 5.  DataFrame.concat (join parameter) 위 df1, df2 데이터프레임을 위/아래로 연결하세요. concat 메서드에서 join='inner'를사용하세요.
pd.concat([df1, df2], axis=0, join='inner')

# 6. pd.concat series 다음 s1, s2 시리즈 객체를 위/아래로 연결하세요.

s1 = pd.Series(['a', 'b'])
s2 = pd.Series(['c', 'd'])

pd.concat([s1, s2], axis=1)df

# 7. pd.concat & ignore_index df1, df2를 concat 메서드로 위/아래로 붙일 때 인덱스를 무시하고 연결하세요.

df1 = pd.DataFrame(np.arange(0, 4).reshape(2,2))
df2 = pd.DataFrame(np.arange(4, 8).reshape(2,2))

pd.concat([df1, df2], ignore_index=True)

# 8. pd.concat 멀티인덱스 df1, df2 데이터프레임을 concat 메서드로 위/아래로 연결할 때 다음 그림과 같이 멀티인덱스로 구성하세요.
index = ["2020", "2021"]

data1 = {
    "PER": [21.09, 13.55],
    "PBR": [2.06, 1.80]
}

data2 = {
    "PER": [12.40, 24.19],
    "PBR": [1.58, 1.44]
}

df1 = pd.DataFrame(data=data1, index=index)
df2 = pd.DataFrame(data=data2, index=index)

pd.concat([df1, df2], keys=["삼성전자", "LG전자"], names=["종목명", "연도"])

#9. 9.  DataFrame.groupby mean 데이터프레임에서 테마별 PER, PBR의 평균을 계산하세요.

data = [
    ["2차전지(생산)", "SK이노베이션", 10.19, 1.29],
    ["해운", "팬오션", 21.23, 0.95],
    ["시스템반도체", "티엘아이", 35.97, 1.12],
    ["해운", "HMM", 21.52, 3.20],
    ["시스템반도체", "아이에이", 37.32, 3.55],
    ["2차전지(생산)", "LG화학", 83.06, 3.75]
]

columns = ["테마", "종목명", "PER", "PBR"]
df9 = pd.DataFrame(data=data, columns=columns)
df9.groupby(by='테마').mean()

#10. DataFrame.groupby max, min 위 데이터프레임에서 테마별 PER, PBR의 최대, 최소값을 계산하세요.
df9.groupby(by='테마').max()
df9.groupby(by='테마').min()

#11. DataFrame.groupby size 위 데이터프레임에서 테마별 종목의 개수를 계산하세요.
df9.groupby(by='테마').size()

#12. DataFrame.groupby get_group 위 데이터프레임을 '테마' 컬럼으로 그룹핑한 후 '2차전지(생산)' 그룹만 가져오세요.
gb = df.groupby(by="테마")
gb.get_group("2차전지(생산)")

#13. DataFrame groupby 위 데이터프레임에서 테마별 PER의 평균을 계산하세요
df9.groupby("테마")<a class="wiki_link" data-title="PER" data-wiki="/page/wiki/PER" href="javascript:void(0)">PER</a>.mean()

#14. DataFrame.groupby 슬라이싱 위 데이터프레임에 대해 테마로 그룹화한 후 PER, PBR 컬럼을 슬라이싱하세요. 그 다음 두 컬럼에 대한 평균을 계산하세요.
df9.groupby("테마")<a class="wiki_link" data-title="PER", "PBR" data-wiki="/page/wiki/PER", "PBR" href="javascript:void(0)">PER", "PBR</a>.mean()

# 시스템 반도체 행만 보이기
df9_g = df9.groupby(by='테마').mean
df9_g.loc[['시스템반도체']]
#15. DataFrame.groupby agg 위 데이터프레임에 대해서 '테마' 컬럼으로 그룹화한 후 max 함수를 적용하세요.
df9.groupby("테마").agg(max)

#16. DataFrame.groupby agg  데이터프레임에 대해서 '테마' 컬럼으로 그룹화한 후 PER 컬럼은 max, PBR 컬럼은 min 함수를 적용해보세요.
df9.groupby("테마").agg({"PER": max, "PBR": min})

# 17. Group 순회 위 데이터프레임에 대해 '테마'로 그룹화 한 후 순회하는 다음 코드를 실행하고 결과를 확인하세요. 아래코드 실행해서 결과 보세요.

for name, group in df.groupby("테마"):
    print(name)
    print(group)

# 18. '테마' 컬럼으로 그룹화한 후 PER, PBR 컬럼에 np.mean과 np.std 함수를 적용하세요.
df9.groupby('테마')[['PER', 'PBR']].agg([np.mean, np.std])

# 19.  nunique'테마' 컬럼을 기준으로 그룹화한 후 종목명 열만 추출하여 데이터의 빈도수를 계산하세요.
df9.groupby('테마')['종목명'].nunique()
# Out:
#             open  high  low  close
# 2022-09-08     0     1   10     11
# 2022-09-07     2     3   12     13
# 2022-09-06     4     5   14     15
# 2022-09-05     6     7   16     17
# 2022-09-02     8     9   18     19

# %%
from IPython.display import Image
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# 출력의 모습 바꾸기 인덱스 번호를 다시 0번부터 붙여 주어서 표
df.groupby(['sex','pclass'])[['survived']].mean().reset_index()

# 생존율 평균구하고 나이 합계 구하기
df.groupby(['sex','pclass'])({'survived','age'}).agg(['mean','sum']) # agg({'PER':max,'PBR':min})

# %%
# 1. DataFrame 생성  데이터프레임을 생성하세요.
import pandas as pd

data = [
    ['Multiples', 'PER', 21.09, 13.55],
    ['Multiples', 'PBR', 2.06, 1.80],
    ['Dividends', 'DPS', 2944, 1444],
    ['Dividends', '배당성향', 78, 25]
]
columns = ['Category', 'Factor', 2020, 2021]
df = pd.DataFrame(data, columns=columns)
df
# 2. DataFrame.set_index (멀티인덱스) set_index 메서드를 사용해서 'Category' 컬럼과 'Factor' 컬럼을 MultiIndex로 설정하세요.
df = df.set_index(['Category','Factor'])
df

# 3. pandas.MultiIndex.from_tuples (로우방향 저장) MultiIndex의 from_tuples 메서드를 사용해서 tuples를 MultiIndex 객체로 생성하세요. 멀티 인덱스의 이름은 ['number','color'] 로 지정하세요.

tuples = [
    ('Multiples', 'PER'),
    ('Multiples', 'PBR'),
    ('Dividends', 'DPS'),
    ('Dividends', '배당성향')
]

index = pd.MultiIndex.from_tuples(tuples,names=['Category','Factor'])
df

# 4. pandas.MultiIndex.from_arrays (컬럼방향 저장) MultiIndex의 from_arrays 메서드를 사용해서 파이썬 이중 리스트를 MultiIndex 객체로 생성하세요. 멀티 인덱스의 이름은 ['number', 'color']​로 지정하세요.

arrays = [
    ['Mutiples', 'Multiples', 'Dividends', 'Dividends'],
    ['PER', 'PBR', 'DPS', '배당성향']
]
index = pd.MultiIndex.from_arrays(arrays,names=['Category','Factor'])
df
# Out:
#                      2020     2021
# Category  Factor
# Multiples PER       21.09    13.55
#           PBR        2.06     1.80
# Dividends DPS     2944.00  1444.00
#           배당성향      78.00    25.00

# %%
# 5. pandas.MultiIndex tuples 변수가 바인딩하는 리스트로부터 먼저 MultiIndex 객체를 생성한 후 데이터프레임 객체를 생성하세요.

import pandas as pd

tuples = [
    ('Multiples', 'PER'),
    ('Multiples', 'PBR'),
    ('Dividends', 'DPS'),
    ('Dividends', '배당성향')
]


data = [
    [21.09, 13.55],
    [2.06, 1.80],
    [2944, 1444],
    [78, 25]
]

columns = [2020, 2021]

df

index = pd.MultiIndex.from_tuples(tuples, names=['Category', 'Factor'])
df = pd.DataFrame(data=data, index=index, columns=columns)

# %% [markdown]
# 붓꽃데이터 응용문제

# %%
iris_url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'
iris_df = pd.read_csv(iris_url, sep=',',encoding='cp949')
iris_df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)
